# %% [markdown]
# #Zomato Data Analytics Project

# %% [markdown]
# Step 1 - Importing Libraries.
#
#
# Pandas is used for Data Manipulation and analysis.
#
# Numpy is used for Numerical operations.
#
# Matplotlib and Seaborn is used for for Data Visualization.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Step 2 - Create Dataframe

# %%
df = pd.read_csv('/content/Zomato data .csv')
print(df)
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB

# %% [markdown]
# #Convert data type of column - Rate

# %%
def handleRate(value):
  value = str(value).split('/')
  value = value[0]
  return float(value)
df['rate'] = df['rate'].apply(handleRate)
print(df.head())
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
sns.countplot(x = df['listed_in(type)'])
plt.xlable("Type of Restaurant")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-61bd028073ec> in <cell line: 0>()
#       1 sns.countplot(x = df['listed_in(type)'])
# ----> 2 plt.xlable("Type of Restaurant")
#       3
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %% [markdown]
# Majority of Restaurant falls in Dining Category

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
grouped_data = df.groupby(['listed_in(type)'])['votes'].sum()
result = pd.DataFrame({'votes':grouped_data})
plt.plot(result, c = "green", marker = "o")
plt.xlabel("Type of Restaurant" , c ="red", size = 20)
plt.ylabel("Total Votes", c ="red", size = 20)
# Out:
# Text(0, 0.5, 'Total Votes')

# %% [markdown]
# Conclusion - Dining Restaurant has recived Maximum votes

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
plt.hist(df['rate'], bins = 5)
plt.title("Ratings Distribution")
# Out:
# Text(0.5, 1.0, 'Ratings Distribution')

# %% [markdown]
# Conclusion - The Majority Restaurant recive Ratings from 3.5 to 4

# %% [markdown]
# # Average order spending by Couples

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
Couple_date = df['approx_cost(for two people)']
sns.countplot(x=Couple_date)
# Out:
# <Axes: xlabel='approx_cost(for two people)', ylabel='count'>

# %% [markdown]
# Conclusion - Majority of couples prefered restaurant with approximate cost of 300 rupees

# %% [markdown]
# #Which mode recives maximum ratings

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
plt.figure(figsize = (6,6))
sns.boxplot(x = 'online_order', y='rate', data = df)
# Out:
# <Axes: xlabel='online_order', ylabel='rate'>

# %% [markdown]
# Conclusion - Offline order recive Lower rating in comparison to online order

# %%
pivot_table = df.pivot_table(index = 'listed_in(type)', columns = 'online_order', aggfunc = 'size', fill_value = 0)
sns.heatmap(pivot_table , annot = True , cmap="YlGnBu", fmt = 'd')
plt.title("Heatmap")
plt.xlabel("online_order")
plt.ylabel("listed_in(type)")
plt.xlable("online_order")
plt.ylable ("listed_in(type)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-053a1686c65c> in <cell line: 0>()
#       4 plt.xlabel("online_order")
#       5 plt.ylabel("listed_in(type)")
# ----> 6 plt.xlable("online_order")
#       7 plt.ylable ("listed_in(type)")
#       8 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %% [markdown]
# Conclusion - Dining Restaurant primarily accept offline orders whereas cafes primarily recive online orders . this suggest that the clint prefers orders in person at Restaurant but prefer online ordering at cafes .
